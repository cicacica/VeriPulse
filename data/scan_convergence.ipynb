# %%
from scan_convergence import scan_convergence
from pathlib import Path

# %%
# check the actual path
data_dir = Path.cwd().parent / "data/dummyless"
print(data_dir, data_dir.exists())

results = scan_convergence(data_dir, verbose=True)

# correct list syntax
not_conv = [r for r in results if not r["converged"]]
print(f"\nNot converged: {len(not_conv)}")
for r in not_conv:
    print(r["file"], r["termination"])
# Out:
# /users/home/gustiani/VeriPulse/data/dummyless True
#
# ────────────────────────────────────────────────────────────
#   Directory : /users/home/gustiani/VeriPulse/data/dummyless
#   Total     : 611
#   Converged : 584
#   NOT conv. : 27
# ────────────────────────────────────────────────────────────
#   Termination reasons:
#      515x  function converged
#       68x  Function converged (within tolerance)
#       15x  Maximum number of iterations reached | Function converged (within tolerance)
#       11x  Function converged (within tolerance) | Maximum number of iterations reached
#        1x  Maximum number of iterations reached
#        1x  Goal achieved | function converged
#
#   Not converged:
#   file                                                    termination                  fid_err         si
#   ─────────────────────────────────────────────────────── ───────────────────────── ────────── ──────────
# ...

# %%
# check the actual path
data_dir = Path.cwd().parent / "data/dummyyes"
print(data_dir, data_dir.exists())

results = scan_convergence(data_dir, verbose=True)

# correct list syntax
not_conv = [r for r in results if not r["converged"]]
print(f"\nNot converged: {len(not_conv)}")
for r in not_conv:
    print(r["file"], r["termination"])
# Out:
# /users/home/gustiani/VeriPulse/data/dummyyes True
#
# ────────────────────────────────────────────────────────────
#   Directory : /users/home/gustiani/VeriPulse/data/dummyyes
#   Total     : 500
#   Converged : 468
#   NOT conv. : 32
# ────────────────────────────────────────────────────────────
#   Termination reasons:
#      395x  function converged
#       73x  Function converged (within tolerance)
#       19x  Function converged (within tolerance) | Maximum number of iterations reached
#       10x  Max wall time exceeded
#        3x  Maximum number of iterations reached | Function converged (within tolerance)
#
#   Not converged:
#   file                                                    termination                  fid_err         si
#   ─────────────────────────────────────────────────────── ───────────────────────── ────────── ──────────
# ...
